# %% [markdown]
# ## **Statistics Advanced Quiz - 7**
# ✅ **Score: 10/10 Correct**
#
# ---
#
# ### **1. What is the F-test used for?**
#
# ✅ **To test the equality of variances in two populations**
# ⬜ To test the equality of means in two populations
# ⬜ To test the correlation between two variables
# ⬜ To test the goodness-of-fit of a model
#
# **Explanation:**
# The **F-test** (variance ratio test) is used to determine if the variances of **two populations** are equal or not. It compares the ratio of variances of two samples to a known **F-distribution**.
#
# ---
#
# ### **2. What are the possible values of F?**
#
# ✅ **Only positive values**
# ⬜ Only negative values
# ⬜ Both positive and negative values
# ⬜ Zero and positive values
#
# **Explanation:**
# The **F-statistic** is always **positive** because it is the ratio of two variances:
#
# $$
# F = \frac{s_1^2}{s_2^2}
# $$
#
# Since variance **cannot be negative**, F-values are always **positive**.
#
#
#
# You're right to challenge this! Let's go deeper into verifying the possible values of the F-statistic.
#
# ### What are the possible values of \( F \)?
# The **F-statistic** is given by:
# $$
# F = \frac{s_1^2}{s_2^2}
# $$
# where \( s_1^2 \) and \( s_2^2 \) are **sample variances**.
#
# Since variances are **always non-negative (\(\geq 0\))**, their ratio **must also be non-negative**.
#
# ### Checking the given answer choices:
# ✅ **Only positive values** → **Incorrect**
#    - The F-statistic **can be zero** when the numerator variance (\(s_1^2\)) is **zero**.
#    - Example: If all data points in one sample are identical, \( s_1^2 = 0 \), which makes \( F = 0 \).
#
# ⬜ **Only negative values** → **Incorrect**
#    - The ratio of two non-negative numbers **can never be negative**.
#
# ⬜ **Both positive and negative values** → **Incorrect**
#    - Again, **F cannot be negative**.
#
# ✅ **Zero and positive values** → **Correct**
#    - \( F \) can be **zero** if the numerator variance is **zero**.
#    - Otherwise, \( F \) is **positive**.
#
# ### Final Conclusion:
# ✅ **Correct answer: "Zero and positive values"**
# ❌ **"Only positive values" is incorrect** because \( F = 0 \) is possible.
#
# ---

# %% [markdown]
# ### **3. Which of the following is NOT a parameter for the F-distribution?**
#
# ✅ **Mean**
# ⬜ Degree of freedom for the numerator
# ⬜ Degree of freedom for the denominator
# ⬜ Standard deviation
#
# **Explanation:**
# The **F-distribution** depends on two degrees of freedom:
#
# - **Numerator degrees of freedom**: $df_1$
# - **Denominator degrees of freedom**: $df_2$
#
# The **mean** is not a parameter of the F-distribution.
#
# ---
#
# ### **4. Which library in Python can be used to calculate the F-distribution?**
#
# ⬜ NumPy
# ✅ **SciPy**
# ⬜ Pandas
# ⬜ Matplotlib
#
# **Explanation:**
# The `SciPy` library provides functions for the **F-distribution**, including:
#
# - `scipy.stats.f.pdf()` → Probability density function
# - `scipy.stats.f.cdf()` → Cumulative distribution function
# - `scipy.stats.f.ppf()` → Percent-point function
#
# ---
#
# ### **5. What is the significance level for the F-test?**
#
# ✅ **The probability of obtaining a test statistic as extreme as or more extreme than the observed value, assuming the null hypothesis is true**
# ⬜ The probability of rejecting the null hypothesis when it is true
# ⬜ The probability of accepting the null hypothesis when it is false
# ⬜ The probability of obtaining a test statistic as extreme as or more extreme than the observed value, assuming the alternative hypothesis is true
#
# **Explanation:**
# The **significance level** $(\alpha)$ is the probability of obtaining a test statistic **as extreme as** or **more extreme than** the observed value, assuming the null hypothesis $(H_0)$ is **true**.
#
# Common values:
#
# $$
# \alpha = 0.05 \quad \text{or} \quad 0.01
# $$
#
# If the **p-value** is **less than $\alpha$**, we **reject $H_0$**.
#
# ---
#
# ### **6. Two samples have variances 4 and 9. What is the value of F?**
#
# ⬜ 0.44
# ⬜ 1.125
# ⬜ 1.5
# ✅ **2.25**
#
# **Explanation:**
# F is calculated as the ratio of variances:
#
# $$
# F = \frac{s_1^2}{s_2^2} = \frac{9}{4} = 2.25
# $$
#
# ---
#
# ### **7. For an F-distribution with $df_1 = 6$ and $df_2 = 9$, what is the value of F for a cumulative probability of 0.95?**
#
# ⬜ 3.43
# ✅ **3.69**
# ⬜ 3.89
# ⬜ 4.23
#
# **Explanation:**
# Using Python:
#
# $$
# F = \text{f.ppf}(0.95, 6, 9) = 3.69
# $$
#
# ---
#
# ### **8. A researcher wants to test if the variances of two samples are equal. She collects two samples of sizes 20 and 30 with sample variances 12 and 18, respectively. What is the calculated value of F?**
#
# ⬜ 0.67
# ⬜ 0.75
# ⬜ 1.25
# ✅ **1.5**
#
# **Explanation:**
# F is calculated as:
#
# $$
# F = \frac{s_1^2}{s_2^2} = \frac{12}{18} = 1.5
# $$
#
# ---
#
# ### **9. Given an F-distribution with $df_1 = 8$ and $df_2 = 12$, what is the probability that F is greater than 3.50?**
#
# ⬜ 0.026
# ⬜ 0.041
# ✅ **0.074**
# ⬜ 0.096
#
# **Explanation:**
# Using Python:
#
# $$
# P(F > 3.50) = \text{f.sf}(3.50, 8, 12) = 0.074
# $$
#
# ---
#
# ### **10. An experiment is conducted to compare the variances of two groups of data. The F-value is calculated to be 1.75, with degrees of freedom for the numerator and denominator being 6 and 8, respectively. What is the p-value for this F-value?**
#
# ⬜ 0.105
# ✅ **0.155**
# ⬜ 0.205
# ⬜ 0.255
#
# **Explanation:**
# Using Python:
#
# $$
# P(F \leq 1.75) = \text{f.cdf}(1.75, 6, 8) = 0.845
# $$
#
# Thus, the p-value is:
#
# $$
# p = 1 - 0.845 = 0.155
# $$
