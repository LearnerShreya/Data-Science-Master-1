# %% [markdown]
# ### Statistics Advance Quiz - 3
#
# **8 out of 8 correct**
#
# ---
#
# **1. What is a hypothesis in statistics?**
#
# - **✅ A guess about the outcome of an experiment.**
#   *(Correct: A hypothesis is an assumption or prediction about the outcome of an experiment or study.)*
#
# - **A proven fact.**
#   *(Incorrect: A hypothesis is not a proven fact; it is an assumption that needs to be tested.)*
#
# - **A random number generator.**
#   *(Incorrect: A hypothesis has nothing to do with random number generation.)*
#
# - **A programming language.**
#   *(Incorrect: A hypothesis is not related to programming languages.)*
#
# **Explanation:** A hypothesis is an assumption or prediction about the outcome of an experiment or study.
#
# ---
#
# **2. What is the mechanism of hypothesis testing?**
#
# - **Analyzing data.**
#   *(Partially correct: Analyzing data is one step in hypothesis testing, but it is not the entire mechanism.)*
#
# - **Conducting experiments.**
#   *(Partially correct: Conducting experiments is part of the process, but it is not the entire mechanism.)*
#
# - **✅ Formulating a null and alternative hypothesis.**
#   *(Correct: The mechanism of hypothesis testing involves formulating a null hypothesis (which assumes there is no effect or relationship between variables) and an alternative hypothesis (which assumes there is an effect or relationship).)*
#
# - **All of the above.**
#   *(Incorrect: While all these steps are part of hypothesis testing, the core mechanism is specifically about formulating hypotheses.)*
#
# **Explanation:** The mechanism of hypothesis testing involves formulating a null hypothesis (which assumes there is no effect or relationship between variables) and an alternative hypothesis (which assumes there is an effect or relationship), collecting data, analyzing the data, and determining whether the null hypothesis can be rejected or not.
#
# ---
#
# **3. What is the significance level commonly used in hypothesis testing?**
#
# - **0.01.**
#   *(Incorrect: While 0.01 is sometimes used, it is not the most common significance level.)*
#
# - **✅ 0.05.**
#   *(Correct: The significance level commonly used in hypothesis testing is 0.05, which means there is a 5% chance of rejecting the null hypothesis when it is actually true.)*
#
# - **0.10.**
#   *(Incorrect: While 0.10 is sometimes used, it is not the most common significance level.)*
#
# - **0.25.**
#   *(Incorrect: 0.25 is rarely used as a significance level in hypothesis testing.)*
#
# **Explanation:** The significance level commonly used in hypothesis testing is 0.05, which means there is a 5% chance of rejecting the null hypothesis when it is actually true. This level of significance is considered the standard in many fields.
#
# ---
#
# **4. Which of the following is a statement that is being tested in hypothesis testing?**
#
# - **Alternative fact.**
#   *(Incorrect: "Alternative fact" is not a term used in hypothesis testing.)*
#
# - **✅ Null hypothesis.**
#   *(Correct: In hypothesis testing, the null hypothesis is the statement that is being tested against the alternative hypothesis.)*
#
# - **Alternative hypothesis.**
#   *(Incorrect: The alternative hypothesis is the statement that is accepted if the null hypothesis is rejected, but it is not the one being tested.)*
#
# - **Alternative reality.**
#   *(Incorrect: "Alternative reality" is not a term used in hypothesis testing.)*
#
# **Explanation:** In hypothesis testing, the null hypothesis is a statement that is being tested against the alternative hypothesis to determine whether there is evidence to reject the null hypothesis.
#
# ---
#
# **5. What is estimation in statistics?**
#
# - **A method used to test hypotheses about a population parameter.**
#   *(Incorrect: Estimation is not about testing hypotheses; it is about inferring population parameters from sample data.)*
#
# - **✅ The process of drawing conclusions about a population based on sample data.**
#   *(Correct: Estimation in statistics is the process of drawing conclusions about a population based on sample data.)*
#
# - **The process of calculating the mean and standard deviation of a population.**
#   *(Incorrect: Estimation is not limited to calculating the mean and standard deviation; it involves inferring population parameters.)*
#
# - **The process of collecting data from a population.**
#   *(Incorrect: Estimation is not about collecting data; it is about using sample data to infer population parameters.)*
#
# **Explanation:** Estimation in statistics is the process of drawing conclusions about a population based on sample data. This involves using sample statistics to make inferences about population parameters.
#
# ---
#
# **6. What is the mechanism of hypothesis testing?**
#
# - **Collecting data, conducting experiments, and analyzing data.**
#   *(Partially correct: These are steps in hypothesis testing, but they do not fully describe the mechanism.)*
#
# - **✅ Formulating a null hypothesis and an alternative hypothesis, collecting data, and analyzing data.**
#   *(Correct: The mechanism of hypothesis testing involves formulating hypotheses, collecting data, and analyzing data to determine whether the null hypothesis can be rejected.)*
#
# - **Calculating the mean and standard deviation of a population.**
#   *(Incorrect: This is not the mechanism of hypothesis testing.)*
#
# - **Drawing conclusions about a population based on sample data.**
#   *(Partially correct: This is part of the process, but it does not fully describe the mechanism.)*
#
# **Explanation:** The mechanism of hypothesis testing involves formulating a null hypothesis and an alternative hypothesis, collecting data, and analyzing data to determine whether the null hypothesis can be rejected or not.
#
# ---
#
# **7. What is a p-value?**
#
# - **The probability of rejecting the null hypothesis.**
#   *(Incorrect: The p-value is not the probability of rejecting the null hypothesis; it is the probability of observing a test statistic as extreme as, or more extreme than, the one observed, assuming the null hypothesis is true.)*
#
# - **✅ The probability of observing a test statistic as extreme as, or more extreme than, the one observed, assuming the null hypothesis is true.**
#   *(Correct: A p-value is the probability of observing a test statistic as extreme as, or more extreme than, the one observed, assuming the null hypothesis is true.)*
#
# - **The probability of observing a test statistic as extreme as, or more extreme than, the one observed, assuming the alternative hypothesis is true.**
#   *(Incorrect: The p-value is calculated under the assumption that the null hypothesis is true, not the alternative hypothesis.)*
#
# - **The probability of observing a test statistic as extreme as, or more extreme than, the one observed, without assuming any hypothesis is true.**
#   *(Incorrect: The p-value is calculated under the assumption that the null hypothesis is true.)*
#
# **Explanation:** A p-value is the probability of observing a test statistic as extreme as, or more extreme than, the one observed, assuming the null hypothesis is true. It is used to determine the statistical significance of the results.
#
# ---
#
# **8. What is the student t distribution?**
#
# - **✅ A probability distribution used to test hypotheses about the mean of a population when the sample size is small.**
#   *(Correct: The student t distribution is used to test hypotheses about the mean of a population when the sample size is small and the population standard deviation is unknown.)*
#
# - **A probability distribution used to test hypotheses about the mean of a population when the sample size is large.**
#   *(Incorrect: For large sample sizes, the normal distribution is typically used instead of the t distribution.)*
#
# - **A measure of central tendency.**
#   *(Incorrect: The t distribution is not a measure of central tendency; it is a probability distribution.)*
#
# - **A measure of variability.**
#   *(Incorrect: The t distribution is not a measure of variability; it is a probability distribution.)*
#
# **Explanation:** The student t distribution is a probability distribution used to test hypotheses about the mean of a population when the sample size is small. It is used when the population standard deviation is unknown and must be estimated from the sample data.
