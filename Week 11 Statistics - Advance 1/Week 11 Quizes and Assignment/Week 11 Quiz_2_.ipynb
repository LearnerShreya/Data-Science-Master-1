# %% [markdown]
# ### Statistics Advance Quiz - 2 DeepSeek
# Confusion : 1,7,5
# **7 out of 7 correct**
#
# ---
#
# **1. What is the difference between a probability mass function (PMF) and a probability density function (PDF)?**
#
# - **A PMF is continuous, while a PDF is discrete.**
#   *(Incorrect: A PMF is used for discrete random variables, while a PDF is used for continuous random variables.)*
#
# - **A PMF is used for continuous random variables, while a PDF is used for discrete random variables.**
#   *(Incorrect: This is the opposite of the correct relationship.)*
#
# - **✅ A PMF gives the probability of a specific outcome, while a PDF gives the probability density of an outcome.**
#   *(Correct: A PMF is used for discrete random variables and gives the probability of a specific outcome. A PDF is used for continuous random variables and gives the probability density, not the probability itself.)*
#
# - **A PMF and a PDF are equivalent terms.**
#   *(Incorrect: They are not equivalent; they are used for different types of random variables.)*
#
# **Explanation:** The PMF is used for discrete random variables, while the PDF is used for continuous random variables.
#
# ---
#
# **2. What does the cumulative density function (CDF) represent?**
#
# - **The probability of a specific outcome.**
#   *(Incorrect: This describes the PMF or PDF, not the CDF.)*
#
# - **The probability density of an outcome.**
#   *(Incorrect: This describes the PDF, not the CDF.)*
#
# - **✅ The cumulative probability up to a specific value.**
#   *(Correct: The CDF gives the probability that a random variable takes on a value less than or equal to a specific value.)*
#
# - **The expected value of a random variable.**
#   *(Incorrect: The expected value is a measure of central tendency, not related to the CDF.)*
#
# **Explanation:** The CDF gives the probability that a random variable takes on a value less than or equal to a specific value.
#
# ---
#
# **3. Which of the following is an example of a normal distribution?**
#
# - **The distribution of the number of heads obtained from flipping a fair coin.**
#   *(Incorrect: This is an example of a binomial distribution.)*
#
# - **The distribution of the sum of two dice rolls.**
#   *(Incorrect: This is an example of a discrete uniform distribution.)*
#
# - **✅ The distribution of heights of adult humans.**
#   *(Correct: Heights of adult humans often follow a normal distribution.)*
#
# - **The distribution of the number of cars passing through a toll booth in one hour.**
#   *(Incorrect: This is an example of a Poisson distribution.)*
#
# **Explanation:** The normal distribution is a continuous probability distribution that is often used to model real-world data, such as the heights of people.
#
# ---
#
# **4. What is the formula for the cumulative distribution function (CDF)?**
#
# - **F(x) = P(X > x)**
#   *(Incorrect: This describes the complementary CDF, not the CDF itself.)*
#
# - **✅ F(x) = P(X < x)**
#   *(Correct: The CDF gives the probability that a random variable X is less than or equal to a certain value x.)*
#
# - **F(x) = P(X = x)**
#   *(Incorrect: This describes the PMF, not the CDF.)*
#
# - **F(x) = P(X >= x)**
#   *(Incorrect: This describes the survival function, not the CDF.)*
#
# **Explanation:** The cumulative distribution function (CDF) gives the probability that a random variable X is less than or equal to a certain value x. It is denoted by F(x) and is defined as F(x) = P(X < x).
#
# ---
#
# **5. What is the Bernoulli distribution?**
#
# - **A distribution used to model the number of successes in a sequence of independent trials.**
#   *(Incorrect: This describes the binomial distribution, not the Bernoulli distribution.)*
#
# - **A distribution used to model the number of occurrences of a particular event in a fixed interval of time.**
#   *(Incorrect: This describes the Poisson distribution.)*
#
# - **A distribution used to model the number of people in a certain age group.**
#   *(Incorrect: This is not related to the Bernoulli distribution.)*
#
# - **A distribution used to model the number of defective items in a production batch.**
#   *(Incorrect: This is not related to the Bernoulli distribution.)*
#
# **Explanation:** The Bernoulli distribution is a discrete probability distribution with only two possible outcomes (success or failure) in a single trial.
#
# The **correct option** for **Question 5** is missing from the list you provided. Let me rewrite the question and include the correct option, along with the explanation:
#
# - **✅ A distribution used to model the outcome of a single trial with two possible outcomes (success or failure).**
#   *(Correct: The Bernoulli distribution is a discrete probability distribution that models a single trial with only two possible outcomes, often labeled as "success" or "failure.")*
#
# **Explanation:** The Bernoulli distribution is a discrete probability distribution with only two possible outcomes (success or failure) in a single trial. It is the foundation for other distributions like the binomial distribution, which extends it to multiple trials.
#
# ---
#
# **6. What is the Uniform distribution?**
#
# - **A distribution used to model the number of occurrences of a particular event in a fixed interval of time.**
#   *(Incorrect: This describes the Poisson distribution.)*
#
# - **A distribution used to model the number of people in a certain age group.**
#   *(Incorrect: This is not related to the Uniform distribution.)*
#
# - **✅ A continuous probability distribution with a constant probability density between two limits.**
#   *(Correct: The Uniform distribution is often used to model situations where all outcomes between two limits are equally likely.)*
#
# - **A discrete probability distribution with equal probabilities for all outcomes.**
#   *(Incorrect: This describes the discrete Uniform distribution, not the continuous Uniform distribution.)*
#
# **Explanation:** The Uniform distribution is often used to model situations where all outcomes between two limits are equally likely.
#
# ---
#
# **7. What are Z-scores used for?**
#
# - **✅ To standardize a normal distribution.**
#   *(Correct: A Z-score is a measure of how many standard deviations a value is from the mean of a normal distribution.)*
#
# - **To compute the probability of a specific outcome in a normal distribution.**
#   *(Incorrect: Z-scores are not directly used to compute probabilities; they are used for standardization.)*
#
# - **To determine if a sample mean is significantly different from a population mean.**
#   *(Incorrect: This describes hypothesis testing, not the purpose of Z-scores.)*
#
# - **To determine the range of values that a random variable is likely to take on.**
#   *(Incorrect: This describes confidence intervals, not Z-scores.)*
#
# **Explanation:** A Z-score is a measure of how many standard deviations a value is from the mean of a normal distribution. By converting a value to a Z-score, we can compare it to other values in the same distribution.
#
# ---
# ---
