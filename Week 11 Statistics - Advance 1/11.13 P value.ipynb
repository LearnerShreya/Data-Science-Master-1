# %% [markdown]
# # 📌 **P-Value (Probability Value)**
#
# The **p-value** is a fundamental concept in statistical hypothesis testing. It quantifies the probability of obtaining a test statistic as extreme or more extreme than the observed value, assuming that the **null hypothesis (H₀)** is true. The p-value helps us decide whether to **reject or fail to reject** the null hypothesis.
#
# ---
#
# ## 📝 **How to Interpret the P-Value?**
#
# ### ✅ **1. Decision Rule**
# - If **p ≤ α** (where **α** is the significance level, typically **0.05** or **0.01**):
#   - There is **strong evidence against** the null hypothesis (**H₀**).
#   - We **reject H₀** (the result is **statistically significant**).
#
# - If **p > α**:
#   - There is **weak evidence against** the null hypothesis (**H₀**).
#   - We **fail to reject H₀** (not enough evidence to conclude significance).
#
# ---
#
# ## 🔢 **Formula for P-Value Calculation**
#
# The p-value is calculated based on a **test statistic** (e.g., Z-score, t-score, chi-square statistic), which follows a known probability distribution.
#
# ### **1️⃣ P-Value for a Z-Test (Normal Distribution)**
#
# For a **Z-test**, we calculate the Z-score using the formula:
#
# **Z = (X̄ - μ) / (σ / √n)**
#
# Where:
# - **X̄** = Sample mean
# - **μ** = Population mean under **H₀**
# - **σ** = Population standard deviation
# - **n** = Sample size
#
# After finding **Z**, we determine the **p-value** from the standard normal table:
#
# - **For a one-tailed test:**
#   - p = P(Z ≥ Z_obs)
#   - or
#   - p = P(Z ≤ Z_obs)
#
# - **For a two-tailed test:**
#   - p = 2 × P(Z ≥ |Z_obs|)
#
# ---
#
# ## 📝 **Example: One-Tailed Z-Test**
#
# A company claims the average weight of its product is **500g**.
# A sample of **30** items has an average weight of **490g**, with a standard deviation of **15g**.
# We test:
#
# - **Null hypothesis (H₀):** The mean weight is **500g**.
# - **Alternative hypothesis (H₁):** The mean weight is **less than 500g** (one-tailed test).
# - **Significance level:** α = 0.05
#
# ### 🔹 **Step 1: Compute the Z-Score**
# **Z = (490 - 500) / (15 / √30) = -10 / 2.74 = -3.65**
#
# ### 🔹 **Step 2: Find the P-Value**
# Using the **Z-table**,
# **P(Z < -3.65) ≈ 0.00013**
#
# Since **0.00013 < 0.05**, we **reject H₀**.
# 🔹 **Conclusion:** The mean weight is significantly **less than 500g**.
#
# ---
#
# ## 📊 **P-Value and Confidence Interval (CI)**
#
# - If the **confidence interval excludes** the hypothesized mean (**μ₀**), then the **p-value is less than α**.
# - If the **confidence interval includes** **μ₀**, then the **p-value is greater than α**.
#
# **Example:**
# For a **95% confidence interval** of **[480g, 498g]** and **μ₀ = 500g**,
# since **500g is outside the range**, the **p-value is small**, leading to rejection of **H₀**.
#
# ---
#
# ## 🎯 **Key Takeaways**
#
# ✔️ The **p-value** helps determine **if results are statistically significant**.
# ✔️ A **small p-value** (**≤ α**) means strong evidence **against H₀**.
# ✔️ The choice of **one-tailed or two-tailed tests** affects the p-value.
# ✔️ **p-value ≠ probability that H₀ is true**, it only measures **evidence against H₀**.
#
# ---
#
# ## 📌 **Would You Like More?**
#
# 🔹 Need explanations for **t-tests**, **chi-square tests**, or another concept? 😊
#
# ---
#
# ## 📌 **Further Reading**
#
# - **Books:**
#   - *Statistics for Engineers and Scientists* by William Navidi
#   - *Introduction to the Practice of Statistics* by David S. Moore
#
# - **Online Resources:**
#   - Khan Academy: Hypothesis Testing and P-Values
#   - Stat Trek: P-Value in Hypothesis Testing
