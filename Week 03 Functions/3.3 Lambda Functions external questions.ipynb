# %% [markdown]
# ### Source : ChatGPT

# %% [markdown]
# **Basic**
#
# 1. Write a lambda function that doubles a number.
# 2. Write a lambda function that takes two numbers and returns their sum.
# 3. Write a lambda function that takes a string and returns its length.
# 4. Write a lambda function that takes a list of numbers and returns the maximum number.
# 5. Write a lambda function that takes a list of strings and returns the longest string.
#
# **Intermediate**
#
# 6. Write a lambda function that takes a list of numbers and returns the average number.
# 7. Write a lambda function that takes a list of strings and returns a list of the lengths of the strings.
# 8. Write a lambda function that takes a list of numbers and returns a list of the even numbers.
# 9. Write a lambda function that takes a list of strings and returns a list of the strings that start with the letter "A".
# 10. Write a lambda function that takes a list of tuples and returns a list of the tuples that contain the number 10.
#
# **Advanced**
#
# 11. Write a lambda function that takes a list of numbers and returns a list of the numbers that are divisible by 3 and 5.
# 12. Write a lambda function that takes a list of strings and returns a list of the strings that contain the substring "abc".
# 13. Write a lambda function that takes a list of tuples and returns a list of the tuples that contain the key "name" and the value "Alice".
# 14. Write a lambda function that takes a list of lists and returns a list of the lists that contain at least one even number.
# 15. Write a lambda function that takes a list of dictionaries and returns a list of the dictionaries that contain the key "age" and the value is greater than 18.
#
# **Bonus**
#
# 16. Write a lambda function that takes a function as an argument and returns a new function that is the composition of the two functions.
# 17. Write a lambda function that takes a list of functions as an argument and returns a new function that is the application of the functions in the list to the input argument.
# 18. Write a lambda function that takes a function and a list of arguments as an argument and returns the result of applying the function to the arguments.
# 19. Write a lambda function that takes a function and a list of keyword arguments as an argument and returns the result of applying the function to the keyword arguments.
# 20. Write a lambda function that takes a function and a list of default arguments as an argument and returns the result of applying the function to the default arguments.
#
# **Advanced**
#
# 21. Write a lambda function that takes a list of strings and returns a list of the strings that are valid email addresses.
# 22. Write a lambda function that takes a list of numbers and returns a list of the numbers that are prime numbers.
# 23. Write a lambda function that takes a list of strings and returns a list of the strings that are unique.
# 24. Write a lambda function that takes a list of lists and returns a list of the lists that are sorted in ascending order.
# 25. Write a lambda function that takes a list of dictionaries and returns a list of the dictionaries that are merged together.

# %% [markdown]
# 1. Write a lambda function to add two numbers.
#
# 2. Create a lambda function to find the square of a number.
#
# 3. Use a lambda function to check if a number is even.
#
# 4. Write a lambda function to reverse a string.
#
# 5. Create a lambda function to calculate the area of a rectangle (length * width).
#
# 6. Use a lambda function to filter out even numbers from a list.
#
# 7. Write a lambda function to convert Celsius to Fahrenheit.
#
# 8. Create a lambda function to find the maximum of three numbers.
#
# 9. Use a lambda function to extract the last word from a sentence.
#
# 10. Write a lambda function to check if a given string is a palindrome.
#
# 11. Create a lambda function to multiply elements of two lists element-wise.
#
# 12. Use a lambda function to find the square root of a number.
#
# 13. Write a lambda function to concatenate two strings with a space in between.
#
# 14. Create a lambda function to count the number of vowels in a string.
#
# 15. Use a lambda function to find the average of a list of numbers.
#
# 16. Write a lambda function to find the sum of digits in a number.
#
# 17. Create a lambda function to remove duplicates from a list.
#
# 18. Use a lambda function to convert a list of temperatures from Celsius to Fahrenheit.
#
# 19. Write a lambda function to find the factorial of a number.
#
# 20. Create a lambda function to sort a list of strings based on the length of each string.
#
# 21. Use a lambda function to find the intersection of two lists.
#
# 22. Write a lambda function to check if a given number is a prime number.
#
# 23. Create a lambda function to find the area of a circle (π * r^2).
#
# 24. Use a lambda function to find the second largest element in a list.
#
# 25. Write a lambda function to calculate the exponential of a number.
