# %% [markdown]
# ### **Quiz: Statistics Basic-2**
#
# ✅ **7 out of 7 correct**
#
# ---
#
# **1. What is the measure of central tendency that is most sensitive to outliers?**
#
# ✅ Mean
# 🔲 Median
# 🔲 Mode
# 🔲 None of the above
#
# **Explanation:** The mean is the average of all the data points and can be heavily influenced by outliers. The median is the middle value of a dataset when arranged in order, and the mode is the most frequent value.
#
# ---
#
# **2. Which of the following is not a measure of dispersion?**
#
# 🔲 Range
# 🔲 Variance
# 🔲 Standard deviation
# ✅ Median
#
# **Explanation:** The median is a measure of central tendency and not a measure of dispersion. Range is the difference between the maximum and minimum values, variance is the average of the squared differences from the mean, and standard deviation is the square root of the variance.
#
# ---
#
# **3. What is a random variable?**
#
# 🔲 A variable that has a single value
# ✅ A variable that can take on any value within a certain range
# 🔲 A variable that is not affected by other variables
# 🔲 A variable that is not used in statistical analysis
#
# **Explanation:** A random variable is a variable that can take on different values within a certain range, often depending on the outcome of a random process.
#
# ---
#
# **4. Which of the following is a subset of a set?**
#
# 🔲 Union
# ✅ Intersection
# 🔲 Complement
# 🔲 Cardinality
#
# **Explanation:** The intersection of two sets is the set of all elements that are in both sets. It is always a subset of both sets.
#
# ---
#
# **5. Which of the following measures of dispersion gives us an idea about the spread of the data around the median?**
#
# 🔲 Variance
# 🔲 Standard deviation
# 🔲 Range
# ✅ Interquartile range
#
# **Explanation:** The interquartile range (IQR) is the range between the first quartile and the third quartile of the data. It gives us an idea about the spread of the data around the median and is less sensitive to outliers compared to other measures of dispersion.
#
# ---
#
# **6. Which of the following is not a set?**
#
# 🔲 {1, 2, 3}
# 🔲 {cat, dog, bird}
# 🔲 {blue, red, green, 4}
# ✅ 5
#
# **Explanation:** A set is a collection of distinct elements, whereas "5" is just a single number, not a collection.
#
# ---
#
# **7. Which measure of dispersion is highly sensitive to outliers?**
#
# ✅ Variance
# 🔲 Standard deviation
# 🔲 Range
# 🔲 Interquartile range
#
# **Explanation:** Variance is highly sensitive to outliers. Since it involves squaring the differences from the mean, the presence of outliers significantly increases its value.
