# %% [markdown]
# # NumPy Quiz: 15/16 Correct
#
# ---
#
# ### 1. What is the purpose of indexing and slicing in NumPy?
#
# - [ ] To change elements in a Numpy array
# - **[x] To extract specific elements or sub-arrays from a Numpy array**
# - [ ] To add elements to a Numpy array
# - [ ] To recreate the array
#
# **Explanation:** Indexing and slicing are used to extract specific elements or sub-arrays from a Numpy array. It allows you to manipulate and extract information from Numpy arrays more easily.
#
# ---
#
# ### 2. How can you access elements in a 2D NumPy array using indexing and slicing?
#
# - [ ] By using one set of square brackets
# - **[x] By using two sets of square brackets**
# - [ ] By using parentheses
# - [ ] By using two sets of parentheses
#
# ---
#
# ### 3. How to perform element-wise multiplication of two arrays of different shapes using broadcasting?
#
# - **[x] `np.multiply(array1, array2)`**
# - [ ] `np.dot(array1, array2)`
# - [ ] `array1 * array2`
# - [ ] All of the above
#
# **Explanation:** `np.multiply(array1, array2)` performs element-wise multiplication and supports broadcasting for arrays of different shapes. `array1 * array2` is commonly used for element-wise multiplication, but `np.multiply` is the preferred function for clarity and explicit broadcasting.
#
# ---
#
# ### 4. How to iterate over a NumPy array and modify elements based on a condition?
#
# - [ ] `for i in np.nditer(array): if i < threshold: i = 0`
# - [ ] `for i in range(np.shape(array)[0]): for j in range(np.shape(array)[1]): if array[i][j] < threshold: array[i][j] = 0`
# - **[x] `array[array < threshold] = 0`**
# - [ ] None
#
# **Explanation:** Option A iterates over elements but doesn't modify them. Option B is correct but inefficient for 2D arrays. Option C is the most concise and efficient, leveraging NumPy's advanced indexing.
#
# ---
#
# ### 5. How to extract all unique elements from a NumPy array?
#
# - **[x] `np.unique(array)`**
# - [ ] `np.distinct(array)`
# - [ ] `np.uniqelements(array)`
# - [ ] All of the above
#
# **Explanation:** `np.unique` is the correct NumPy function to extract unique elements. The other options are not valid NumPy functions.
#
# ---
#
# ### 6. What does the `np.concatenate()` function do in NumPy?
#
# - [ ] It adds two arrays element-wise
# - **[x] It merges two or more arrays into a single array**
# - [ ] It performs a dot product between two arrays
# - [ ] It subtracts two arrays element-wise
#
# **Explanation:** `np.concatenate()` merges two or more arrays along a specified axis into a single array.
#
# ---
#
# ### 7. Which of the following operators is used to perform element-wise multiplication of two arrays in NumPy?
#
# - [ ] `+`
# - **[x] `*`**
# - [ ] `/`
# - [ ] `-`
#
# ---
#
# ### 8. What does the `np.char.upper()` function do in NumPy?
#
# - [ ] It returns the length of each string in an array
# - [ ] It sorts an array of strings in alphabetical order
# - **[x] It converts each string in an array to uppercase**
# - [ ] It returns the index of the first occurrence of a substring in a string array
#
# ---
#
# ### 9. Which of the following functions can be used to calculate the standard deviation of an array in NumPy?
#
# - [ ] `np.mean()`
# - [ ] `np.median()`
# - [ ] `np.var()`
# - **[x] `np.std()`**
#
# ---
#
# ### 10. What does the `np.power()` function do in NumPy?
#
# - [ ] It performs element-wise addition of two arrays
# - [ ] It calculates the square root of each element in an array
# - **[x] It raises each element in an array to a specified power**
# - [ ] It performs matrix multiplication of two arrays
#
# ---
#
# ### 11. Which of the following operators is used to perform element-wise division of two arrays in NumPy?
#
# - [ ] `+`
# - [ ] `*`
# - **[x] `/`**
# - [ ] `-`
#
# ---
#
# ### 12. What does the `np.flip()` function do in NumPy?
#
# - **[x] It reverses the order of elements in an array**
# - [ ] It reshapes an array into a specified shape
# - [ ] It sorts an array in ascending order
# - [ ] It returns the cumulative sum of elements in an array
#
# ---
#
# ### 13. What does the `np.argsort()` function do in NumPy?
#
# - **[x] It returns the indices that would sort an array**
# - [ ] It searches for the maximum value in an array
# - [ ] It returns the number of occurrences of a specified element in an array
# - [ ] It counts the number of elements in an array that satisfy a specified condition
#
# ---
#
# ### 14. Which of the following functions can be used to count the number of occurrences of a specified element in an array in NumPy?
#
# - [ ] `np.argmax()`
# - [ ] `np.argsort()`
# - **[x] `np.count_nonzero()`**
# - [ ] `np.flip()`
#
# ---
#
# ### 15. What does the `np.transpose()` function do in NumPy?
#
# - [ ] It returns the dot product of two arrays
# - [ ] It returns the inverse of a matrix
# - **[x] It returns a view of the array with axes transposed**
# - [ ] It returns the eigenvalues of a matrix
#
# ---
#
# ### 16. Which of the following functions can be used to swap the byte order of an array in NumPy?
#
# - [ ] `np.ndarray.copy()`
# - [ ] `np.dot()`
# - **[x] `np.byteswap()`**
# - [ ] `np.diag()`
#
# **Explanation:** `np.byteswap()` swaps the byte order of an array.
