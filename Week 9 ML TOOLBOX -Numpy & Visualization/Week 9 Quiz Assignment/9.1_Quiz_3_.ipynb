# %% [markdown]
# ### **Seaborn Quiz**
#
# ---
#
# 1. **How would you create a histogram in Seaborn?**
#
# 🔲 sns.hist(data)
# 🔲 sns.histogram(data)
# 🔲 sns.histograms(data)
# ✅ sns.histplot(data)
#
# **Explanation:** The sns.histplot function is used to create a histogram in Seaborn. It allows customization of bin sizes, colors, and other parameters to enhance data visualization.
#
# ---
#
# 2. **How would you create a scatter plot in Seaborn?**
#
# 🔲 sns.scatter(x, y)
# ✅ sns.scatterplot(x, y)
# 🔲 sns.scatterplots(x, y)
# 🔲 sns.scatter_plot(x, y)
#
# **Explanation:** The sns.scatterplot function is used to create a scatter plot in Seaborn. It plots individual points based on the provided x and y values, helping to visualize relationships between two variables.
#
# ---
#
# 3. **How would you create a bar plot in Seaborn?**
#
# 🔲 sns.bar(x, y)
# ✅ sns.barplot(x, y)
# 🔲 sns.barplots(x, y)
# 🔲 sns.bar_plot(x, y)
#
# **Explanation:** The sns.barplot function is used to create a bar plot in Seaborn. It aggregates categorical data and displays it using rectangular bars, making it useful for comparing different groups.
#
# ---
#
# 4. **How would you create a box plot in Seaborn?**
#
# 🔲 sns.box(data)
# ✅ sns.boxplot(data)
# 🔲 sns.boxplots(data)
# 🔲 sns.box_plot(data)
#
# **Explanation:** The sns.boxplot function is used to create a box plot in Seaborn. It visualizes the distribution of data based on five-number summary statistics (minimum, first quartile, median, third quartile, and maximum).
#
# ---
#
# 5. **How would you create a violin plot in Seaborn?**
#
# 🔲 sns.violin(data)
# ✅ sns.violinplot(data)
# 🔲 sns.violinplots(data)
# 🔲 sns.violin_plot(data)
#
# **Explanation:** The sns.violinplot function creates a violin plot in Seaborn, which combines aspects of box plots and KDE plots to show data distribution and density in a single visualization.
#
# ---
#
# 6. **How would you create a line plot in Seaborn?**
#
# 🔲 sns.line(x, y)
# ✅ sns.lineplot(x, y)
# 🔲 sns.lineplots(x, y)
# 🔲 sns.line_plot(x, y)
#
# **Explanation:** The sns.lineplot function is used to create a line plot in Seaborn. It connects data points with a continuous line, making it useful for trend analysis over time.
#
# ---
#
# 7. **How would you create a KDE plot in Seaborn?**
#
# 🔲 sns.kde(data)
# ✅ sns.kdeplot(data)
# 🔲 sns.kdeplots(data)
# 🔲 sns.kde_plot(data)
#
# **Explanation:** The sns.kdeplot function is used to create a kernel density estimation (KDE) plot in Seaborn. It smooths data distributions to provide insights into data density.
