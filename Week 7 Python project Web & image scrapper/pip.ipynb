# %% [markdown]
# ```python
# pip list
# ```

# %% [markdown]
# ```bash
# pip install pymongo
# pip install mysql-connector-python
# pip install flask
# pip install requests
# pip install flask_cors
# ```

# %% [markdown]
# Here’s a list of common Python libraries for data science, along with installation commands and their purposes:
#
# ---
#
# ### **Data Manipulation and Analysis**
# 1. **pandas**: Data manipulation and analysis.
#    ```bash
#    pip install pandas
#    ```
#
# 2. **numpy**: Numerical computations and array operations.
#    ```bash
#    pip install numpy
#    ```
#
# 3. **dask**: Parallel computing for larger-than-memory datasets.
#    ```bash
#    pip install dask
#    ```
#
# ---
#
# ### **Data Visualization**
# 4. **matplotlib**: Plotting and visualizations.
#    ```bash
#    pip install matplotlib
#    ```
#
# 5. **seaborn**: Statistical data visualization (built on matplotlib).
#    ```bash
#    pip install seaborn
#    ```
#
# 6. **plotly**: Interactive plotting.
#    ```bash
#    pip install plotly
#    ```
#
# 7. **bokeh**: Interactive visualization for web applications.
#    ```bash
#    pip install bokeh
#    ```
#
# ---
#
# ### **Machine Learning and AI**
# 8. **scikit-learn**: Machine learning models and tools.
#    ```bash
#    pip install scikit-learn
#    ```
#
# 9. **tensorflow**: Deep learning framework by Google.
#    ```bash
#    pip install tensorflow
#    ```
#
# 10. **keras**: High-level neural networks API (uses TensorFlow as backend).
#     ```bash
#     pip install keras
#     ```
#
# 11. **pytorch**: Deep learning framework by Facebook.
#     ```bash
#     pip install torch torchvision torchaudio
#     ```
#
# 12. **xgboost**: Gradient boosting for supervised learning.
#     ```bash
#     pip install xgboost
#     ```
#
# 13. **lightgbm**: Gradient boosting framework.
#     ```bash
#     pip install lightgbm
#     ```
#
# 14. **catboost**: Gradient boosting framework.
#     ```bash
#     pip install catboost
#     ```
#
# ---
#
# ### **Natural Language Processing (NLP)**
# 15. **nltk**: Natural language toolkit.
#     ```bash
#     pip install nltk
#     ```
#
# 16. **spacy**: NLP library for tokenization, parsing, and more.
#     ```bash
#     pip install spacy
#     ```
#
# 17. **transformers**: Hugging Face library for large pre-trained language models.
#     ```bash
#     pip install transformers
#     ```
#
# ---
#
# ### **Data Collection and Web Scraping**
# 18. **requests**: HTTP requests library.
#     ```bash
#     pip install requests
#     ```
#
# 19. **beautifulsoup4**: Web scraping library.
#     ```bash
#     pip install beautifulsoup4
#     ```
#
# 20. **selenium**: Browser automation and web scraping.
#     ```bash
#     pip install selenium
#     ```
#
# 21. **scrapy**: Web scraping framework.
#     ```bash
#     pip install scrapy
#     ```
#
# ---
#
# ### **Database Interaction**
# 22. **pymongo**: MongoDB interaction.
#     ```bash
#     pip install pymongo
#     ```
#
# 23. **mysql-connector-python**: MySQL interaction.
#     ```bash
#     pip install mysql-connector-python
#     ```
#
# 24. **sqlalchemy**: SQL toolkit and ORM.
#     ```bash
#     pip install sqlalchemy
#     ```
#
# 25. **psycopg2**: PostgreSQL interaction.
#     ```bash
#     pip install psycopg2
#     ```
#
# ---
#
# ### **Big Data and Distributed Computing**
# 26. **pyspark**: Interface for Apache Spark.
#     ```bash
#     pip install pyspark
#     ```
#
# 27. **hdfs**: Interact with HDFS systems.
#     ```bash
#     pip install hdfs
#     ```
#
# 28. **mrjob**: Hadoop MapReduce jobs in Python.
#     ```bash
#     pip install mrjob
#     ```
#
# ---
#
# ### **Data Engineering and Preprocessing**
# 29. **pyarrow**: Columnar data formats like Parquet and Arrow.
#     ```bash
#     pip install pyarrow
#     ```
#
# 30. **openpyxl**: Read and write Excel files.
#     ```bash
#     pip install openpyxl
#     ```
#
# 31. **xlrd**: Read Excel files (old-style).
#     ```bash
#     pip install xlrd
#     ```
#
# 32. **pytables**: Work with HDF5 files.
#     ```bash
#     pip install tables
#     ```
#
# ---
#
# ### **Other Useful Libraries**
# 33. **statsmodels**: Statistical models and tests.
#     ```bash
#     pip install statsmodels
#     ```
#
# 34. **scipy**: Scientific computing.
#     ```bash
#     pip install scipy
#     ```
#
# 35. **dash**: Interactive web applications for data visualization.
#     ```bash
#     pip install dash
#     ```
#
# 36. **fastapi**: API framework for machine learning deployments.
#     ```bash
#     pip install fastapi
#     ```
#
# 37. **flask**: Web framework for serving machine learning models.
#     ```bash
#     pip install flask
#     ```
#
# 38. **pytest**: Testing framework for Python.
#     ```bash
#     pip install pytest
#     ```
#
# ---
#
# Let me know if you'd like additional recommendations or help installing!

# %% [markdown]
# ---
# ---
#
# ```python
# pip list
#
#
# C:\Users\singh>python -m pip list
# Package                   Version
# ------------------------- --------------
# anyio                     4.6.2.post1
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# blinker                   1.9.0
# bs4                       0.0.2
# certifi                   2024.8.30
# cffi                      1.17.1
# charset-normalizer        3.4.0
# click                     8.1.8
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# debugpy                   1.8.9
# decorator                 5.1.1
# defusedxml                0.7.1
# dnspython                 2.7.0
# executing                 2.1.0
# fastjsonschema            2.21.0
# Flask                     3.1.0
# Flask-Cors                5.0.0
# fonttools                 4.55.3
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.7
# httpx                     0.28.0
# idna                      3.10
# ipykernel                 6.29.5
# ipython                   8.30.0
# ipywidgets                8.1.5
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.2
# Jinja2                    3.1.5
# json5                     0.10.0
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2024.10.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.3.3
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# kiwisolver                1.4.7
# MarkupSafe                3.0.2
# matplotlib                3.10.0
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# mysql-connector-python    9.1.0
# nbclient                  0.10.1
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.3.1
# notebook_shim             0.2.4
# numpy                     2.2.0
# overrides                 7.7.0
# packaging                 24.2
# pandocfilters             1.5.1
# parso                     0.8.4
# pillow                    11.0.0
# pip                       24.3.1
# platformdirs              4.3.6
# prometheus_client         0.21.0
# prompt_toolkit            3.0.48
# psutil                    6.1.0
# pure_eval                 0.2.3
# pycparser                 2.22
# Pygments                  2.18.0
# pymongo                   4.10.1
# pyparsing                 3.2.0
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pywin32                   308
# pywinpty                  2.0.14
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.21.0
# Send2Trash                1.8.3
# setuptools                75.6.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.4.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20241003
# uri-template              1.3.0
# urllib3                   2.2.3
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  3.1.3
# widgetsnbextension        4.0.13
#
# C:\Users\singh>
# ```
