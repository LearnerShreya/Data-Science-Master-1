# %% [markdown]
# # **EDA Quiz - 1**
# **Score: 8/8 Correct**
#
# ---
#
# ## **1. Which feature(s) in the Wine Quality dataset exhibit non-normality?**
#
# ✅ **Residual sugar**
# ⬜ Fixed acidity
# ⬜ pH
# ⬜ Alcohol
#
# ### **Explanation:**
# The **Residual sugar** feature exhibits **non-normality**, as confirmed by the EDA analysis.
# - The **histogram** and **Q-Q plot** show a **non-normal distribution with a positive skew**.
# - Other features like **fixed acidity, pH, and alcohol** exhibit normal or nearly normal distributions.
#
# ---
#
# ## **2. Which transformation(s) can be applied to the non-normal features in the Wine Quality dataset to improve normality?**
#
# ✅ **All of the above**
# ⬜ Logarithmic transformation
# ⬜ Square root transformation
# ⬜ Exponential transformation
#
# ### **Explanation:**
# To improve normality in non-normal features, various transformation methods can be applied:
# - **Logarithmic transformation** reduces skewness.
# - **Square root transformation** is useful for moderate skewness.
# - **Exponential transformation** can also be used in some cases.
#
# Since all these methods can help, the correct answer is **"All of the above."**
#
# ---
#
# ## **3. What is the most important feature for predicting wine quality according to the feature importance ranking?**
#
# ⬜ pH
# ✅ **Alcohol**
# ⬜ Density
# ⬜ Sulphates
#
# ### **Explanation:**
# The **alcohol content** is the most important predictor of **wine quality**.
# - **Higher alcohol content** is generally associated with **higher quality ratings**.
# - Other features like **volatile acidity, sulphates, and citric acid** also play a role but are **less important**.
#
# ---
#
# ## **4. What feature(s) in the Wine Quality dataset have the highest correlation with wine quality?**
#
# ✅ **All of the above**
# ⬜ Chlorides
# ⬜ Total sulfur dioxide
# ⬜ Citric acid
#
# ### **Explanation:**
# According to correlation analysis, the features **Chlorides, Total sulfur dioxide, and Citric acid** have the **highest correlation** with wine quality.
# - These features strongly impact **overall quality ratings**.
# - Other features, like **pH, density, and residual sugar**, show **moderate correlation**.
#
# ---
#
# ## **5. What is the purpose of feature engineering in machine learning?**
#
# ⬜ To increase the size of the dataset
# ✅ **To extract useful information from the raw data**
# ⬜ To make the dataset more complex
# ⬜ None of the above
#
# ### **Explanation:**
# **Feature engineering** is the process of **transforming raw data** into meaningful **features** for better model performance.
# - It **extracts useful information** and **improves predictive accuracy**.
# - It does **not** increase dataset size or add unnecessary complexity.
#
# ---
#
# ## **6. Which feature selection technique uses tree-based models to rank the importance of each feature in predicting the target variable?**
#
# ⬜ Correlation analysis
# ⬜ Principal component analysis
# ⬜ Model-based selection
# ✅ **Feature importance ranking**
#
# ### **Explanation:**
# **Feature importance ranking** uses **tree-based models** (e.g., Decision Trees, Random Forests) to measure the impact of each feature.
# - Features **highly impacting** prediction accuracy are **retained**, while **irrelevant** ones are **removed**.
#
# ---
#
# ## **7. What is the main goal of analyzing students' performance in exams?**
#
# ✅ **All of the above**
# ⬜ To evaluate the quality of teaching
# ⬜ To predict future performance
# ⬜ To identify areas for improvement
#
# ### **Explanation:**
# Exam analysis serves **multiple purposes**:
# - **Evaluates teaching effectiveness**.
# - **Predicts future student performance**.
# - **Identifies areas where students need improvement**.
#
# ---
#
# ## **8. Which feature in the Students Performance dataset has the strongest correlation with math scores?**
#
# ⬜ Parental education
# ⬜ Test preparation course
# ✅ **Lunch**
# ⬜ None of the above
#
# ### **Explanation:**
# The **"lunch" feature** has the **strongest correlation** with **math scores**.
# - It acts as a **proxy for socio-economic status**.
# - Students receiving **free/reduced-price lunch** often score **lower**, highlighting **economic impact on education**.
#
# ---
#
# 🎉 **Well done! Perfect score (8/8)!** 🎯
